# %% [markdown]
# <a href="https://colab.research.google.com/github/rlpinhal/Aprendendo_Python/blob/main/aula_2_arrays.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#variaveis globais do sistema em uma array variavel = [], no qual armazena diversas variáveis como se fosse uma lista
alunos =["Rafael","Jessica","Erick","Taynara","Rafael P"]

#exibir os dados da lista
print(alunos)
#exibir um item da lista - chama a lista e seu index list[index]
# Out:
# ['Rafael', 'Jessica', 'Erick', 'Taynara', 'Rafael P']
