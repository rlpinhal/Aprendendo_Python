# %% [markdown]
# <a href="https://colab.research.google.com/github/rlpinhal/Aprendendo_Python/blob/main/aula_17_scrapping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# para o trabalho com coleta de informações
# 1 - entrada manual - usuario informa dados
# 2 - raspagem de dados - web scraping - entra em um site e coleta seus dados
# 3 - importacao/automacao - sensores, apis

#vamos usar web scraping para coletar dados de noticias
import requests
import pandas as pd

#para puxar uma função especifica de uma biblioteca, nao precisamos dela toda,
#from BIBLIOTECA import FUNÇÃO
from datetime import datetime

#temos que importar uma biblioteca de web scraping
from bs4 import BeautifulSoup

# %%
#vamos criar a função para coletar os dados do site alvo
def coletar_noticias_g1():
  url_g1='https://g1.globo.com/'

  #vamos usar um agente para que o site não bloqueie a nossa requisição
  headers ={
      'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/110.0.0.0 Safari/537.36'
  }

  #agora vamos condicionar nosso uso
  try:
    resposta = requests.get(url_g1, headers=headers)
    #eu qquero verificar se deu tudo certo, como se eu tivesse usado status code
    resposta.raise_for_status()

    #vou conectar o web scrap para coletar os dados para nós
    # variavel = chama a biblioteca (método qeu armazena (response.text),atributo de coleta)
    soup = BeautifulSoup(resposta.text,'html.parser')

    #de onde vamos pegar as informações
    #comando find.all('a', class_='feed_post_link') -> encontre tudo
    #tags - p - texto paragrafo
    #a ou href - link
    #img - imagem
    #h1,h2,h3 - cabeçalhos
    # video

    posts = soup.find_all('a', class_='feed-post-link')

    lista_noticias =[]

    for i in posts:
      titulo = i.get_text()
      link = i.get('href')
      lista_noticias.append({'Titulo':titulo,
                             'Link':link,
                             'Data':datetime.now().strftime('%d/%m/%y')})

    df_noticias = pd.DataFrame(lista_noticias)


    #dentro do try, para mostrar os dados sempre é legal trazer o return
    return df_noticias

  except Exception as e:
    print('Não consegui ler as noticias')
    return None

# %%
noticias = coletar_noticias_g1()
if noticias is not None:
  display(noticias.head(10))
# Out:
#                                               Titulo  \
# 0  Aumento de capital pressiona caixa do DF, que ...
# 1  Candidata a miss morre ao cair de apartamento;...
# 2  Empresário é morto a tiros durante abordagem d...
# 3  Irã diz que apreendeu 2 navios após Trump este...
# 4  'Cale a boca, Trump': Irã zomba de extensão de...
# 5  Entenda a liberação de Ramagem nos EUA e a exp...
# 6  Novo Minha Casa, Minha Vida passa a valer hoje...
# 7  Onda de calor, chuva intensa no Norte e frio c...
#
#                                                 Link      Data
# 0  https://g1.globo.com/economia/blog/ana-flor/po...  22/04/26
# 1  https://g1.globo.com/rj/rio-de-janeiro/noticia...  22/04/26
# 2  https://g1.globo.com/rj/rio-de-janeiro/noticia...  22/04/26
# 3  https://g1.globo.com/mundo/ao-vivo/eua-ataque-...  22/04/26
# 4  https://g1.globo.com/mundo/noticia/2026/04/22/...  22/04/26
# 5  https://g1.globo.com/politica/noticia/2026/04/...  22/04/26
# 6  https://g1.globo.com/economia/noticia/2026/04/...  22/04/26
# 7  https://g1.globo.com/meio-ambiente/noticia/202...  22/04/26
