# %% [markdown]
# <a href="https://colab.research.google.com/github/rlpinhal/Aprendendo_Python/blob/main/aula_12_aplica%C3%A7%C3%A3ooutrasbibliotecas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# em geral um banco de dados não está no python
# um banco de dados é conectado a um backend
# é comum ser em sql - firebase - supabase - postgree
# vamos criar nossa base de dados vazia

usuarios = {}

# função de cadastro e de login

def cadastrar():
  novo_usuario = input ('Informe o nome do usuario: ')
  nova_senha = input('Informe a senha: ')

  #para adicionar um valor no dicionário
  #dicionario[chave] = valor

  usuarios[novo_usuario] = nova_senha
  print('Usuário cadastrado com sucesso')

import getpass
def login():
  usuario = input('Informe seu usuário: ')
  senha=getpass.getpass('Informe sua senha: ')

  # vamos verificar se o usuario digitado esta no dicionario usuarios
  if usuario in usuarios and usuarios[usuario] == senha:
    print('Login realizado com sucesso')

  else:
    print('Usuário ou senha inválidos')

# executar o sistema
while True:
  #executa um loop sem condição e é finalizado com o break
  print('\n1 - Cadastrar novo usuário')
  print('2 - Ver usuários cadastrados')
  print('3 - Ver senhas cadastradas')
  print('4 - Ver usuários e senhas')
  print('5 - Logar')
  print('0 - Sair do sistema')

  op = input('Informe sua escolha: ')

  if op == '1':
    cadastrar()
  if op == '2':
    print(usuarios.keys())
    # a função dicionario.keys() - exibe todas as chaves cadastradas
  elif op == '3':
    print(usuarios.values())
    # a função dicionario.values() - exibe todos os valores cadastrados
  elif op == '4':
    print(usuarios.items())
    # a função dicionario.items() - exibe todas as combinações cadastradas
  elif op == '5':
    login()
  elif op == '0':
    break
  else:
    print ('Opcão não encontrada')
# Out:
# 1 - Cadastrar novo usuário
# 2 - Ver usuários cadastrados
# 3 - Ver senhas cadastradas
# 4 - Ver usuários e senhas
# 5 - Logar
# 0 - Sair do sistema
# Informe sua escolha: 3
# dict_values([])
#
# 1 - Cadastrar novo usuário
# 2 - Ver usuários cadastrados
# 3 - Ver senhas cadastradas
# 4 - Ver usuários e senhas
# 5 - Logar
# 0 - Sair do sistema
# Informe sua escolha: 0
